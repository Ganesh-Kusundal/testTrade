# %%
"""Gateway v0/v1 API — usage examples.

Run from project root:
    python examples/gateway_api_examples.py

Requires .env with DHAN_ACCESS_TOKEN, DHAN_CLIENT_ID etc.
"""
from __future__ import annotations

import os
import sys
from datetime import date
from decimal import Decimal

# Ensure project root is on sys.path
sys.path.insert(0, os.getcwd())

from dotenv import load_dotenv

load_dotenv()

from scalpr.brokers.gateway import Gateway

# Default — uses .env credentials
gw = Gateway()
print(f"Gateway created: {gw}")
# Out:
# Gateway created: <scalpr.brokers.gateway.facade.Gateway object at 0x106d99940>

# %%
reliance = gw.instrument("RELIANCE", 'NSE')
reliance.historical()
# Out:
# [{'timestamp': datetime.datetime(2026, 4, 28, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1392.0'),
#   'high': Decimal('1433.8'),
#   'low': Decimal('1391.3'),
#   'close': Decimal('1425.4'),
#   'volume': 30542143},
#  {'timestamp': datetime.datetime(2026, 4, 29, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1409.0'),
#   'high': Decimal('1437.0'),
#   'low': Decimal('1393.1'),
#   'close': Decimal('1430.8'),
#   'volume': 30957881},
#  {'timestamp': datetime.datetime(2026, 5, 3, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1433.4'),
#   'high': Decimal('1467.4'),
#   'low': Decimal('1433.4'),
#   'close': Decimal('1463.1'),
#   'volume': 24035700},
#  {'timestamp': datetime.datetime(2026, 5, 4, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1460.0'),
#   'high': Decimal('1473.4'),
#   'low': Decimal('1450.0'),
#   'close': Decimal('1463.6'),
#   'volume': 23543341},
#  {'timestamp': datetime.datetime(2026, 5, 5, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1463.0'),
#   'high': Decimal('1473.3'),
#   'low': Decimal('1427.5'),
#   'close': Decimal('1437.9'),
#   'volume': 14221786},
#  {'timestamp': datetime.datetime(2026, 5, 6, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1438.8'),
#   'high': Decimal('1449.5'),
#   'low': Decimal('1430.3'),
#   'close': Decimal('1436.2'),
#   'volume': 19816903},
#  {'timestamp': datetime.datetime(2026, 5, 7, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1426.0'),
#   'high': Decimal('1442.8'),
#   'low': Decimal('1417.5'),
#   'close': Decimal('1435.2'),
#   'volume': 8663105},
#  {'timestamp': datetime.datetime(2026, 5, 10, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1420.0'),
#   'high': Decimal('1428.0'),
#   'low': Decimal('1382.0'),
#   'close': Decimal('1388.2'),
#   'volume': 15261787},
#  {'timestamp': datetime.datetime(2026, 5, 11, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1392.0'),
#   'high': Decimal('1393.5'),
#   'low': Decimal('1360.3'),
#   'close': Decimal('1364.0'),
#   'volume': 24357500},
#  {'timestamp': datetime.datetime(2026, 5, 12, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1361.4'),
#   'high': Decimal('1372.4'),
#   'low': Decimal('1352.4'),
#   'close': Decimal('1358.8'),
#   'volume': 13797989},
#  {'timestamp': datetime.datetime(2026, 5, 13, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1365.2'),
#   'high': Decimal('1378.0'),
#   'low': Decimal('1358.4'),
#   'close': Decimal('1361.8'),
#   'volume': 17303059},
#  {'timestamp': datetime.datetime(2026, 5, 14, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1356.8'),
#   'high': Decimal('1364.8'),
#   'low': Decimal('1329.2'),
#   'close': Decimal('1336.4'),
#   'volume': 19976192},
#  {'timestamp': datetime.datetime(2026, 5, 17, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1334.0'),
#   'high': Decimal('1342.0'),
#   'low': Decimal('1318.7'),
#   'close': Decimal('1335.9'),
#   'volume': 13022473},
#  {'timestamp': datetime.datetime(2026, 5, 18, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1338.7'),
#   'high': Decimal('1344.0'),
#   'low': Decimal('1318.4'),
#   'close': Decimal('1322.7'),
#   'volume': 21665501},
#  {'timestamp': datetime.datetime(2026, 5, 19, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1318.7'),
#   'high': Decimal('1362.9'),
#   'low': Decimal('1312.6'),
#   'close': Decimal('1359.7'),
#   'volume': 13248515},
#  {'timestamp': datetime.datetime(2026, 5, 20, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1367.2'),
#   'high': Decimal('1370.9'),
#   'low': Decimal('1345.2'),
#   'close': Decimal('1349.6'),
#   'volume': 17150630},
#  {'timestamp': datetime.datetime(2026, 5, 21, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1350.0'),
#   'high': Decimal('1367.4'),
#   'low': Decimal('1349.1'),
#   'close': Decimal('1354.5'),
#   'volume': 7105813},
#  {'timestamp': datetime.datetime(2026, 5, 24, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1366.8'),
#   'high': Decimal('1371.1'),
#   'low': Decimal('1357.0'),
#   'close': Decimal('1367.0'),
#   'volume': 6750071},
#  {'timestamp': datetime.datetime(2026, 5, 25, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1360.1'),
#   'high': Decimal('1368.5'),
#   'low': Decimal('1352.4'),
#   'close': Decimal('1356.3'),
#   'volume': 13769747},
#  {'timestamp': datetime.datetime(2026, 5, 26, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1353.0'),
#   'high': Decimal('1361.0'),
#   'low': Decimal('1348.6'),
#   'close': Decimal('1350.5'),
#   'volume': 13215138},
#  {'timestamp': datetime.datetime(2026, 5, 28, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1364.0'),
#   'high': Decimal('1369.0'),
#   'low': Decimal('1317.0'),
#   'close': Decimal('1321.2'),
#   'volume': 42634247},
#  {'timestamp': datetime.datetime(2026, 5, 31, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1332.5'),
#   'high': Decimal('1335.5'),
#   'low': Decimal('1318.5'),
#   'close': Decimal('1320.0'),
#   'volume': 10700603},
#  {'timestamp': datetime.datetime(2026, 6, 1, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1307.7'),
#   'high': Decimal('1327.8'),
#   'low': Decimal('1300.3'),
#   'close': Decimal('1314.6'),
#   'volume': 23302785},
#  {'timestamp': datetime.datetime(2026, 6, 2, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1315.0'),
#   'high': Decimal('1324.0'),
#   'low': Decimal('1301.0'),
#   'close': Decimal('1313.2'),
#   'volume': 20012293},
#  {'timestamp': datetime.datetime(2026, 6, 3, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1301.0'),
#   'high': Decimal('1311.2'),
#   'low': Decimal('1293.1'),
#   'close': Decimal('1303.7'),
#   'volume': 23474327},
#  {'timestamp': datetime.datetime(2026, 6, 4, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1304.5'),
#   'high': Decimal('1306.0'),
#   'low': Decimal('1288.0'),
#   'close': Decimal('1291.0'),
#   'volume': 17785223},
#  {'timestamp': datetime.datetime(2026, 6, 7, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1277.0'),
#   'high': Decimal('1282.6'),
#   'low': Decimal('1259.2'),
#   'close': Decimal('1263.3'),
#   'volume': 16494759},
#  {'timestamp': datetime.datetime(2026, 6, 8, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1269.0'),
#   'high': Decimal('1274.2'),
#   'low': Decimal('1257.5'),
#   'close': Decimal('1269.2'),
#   'volume': 23620214},
#  {'timestamp': datetime.datetime(2026, 6, 9, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1275.0'),
#   'high': Decimal('1300.5'),
#   'low': Decimal('1254.4'),
#   'close': Decimal('1258.8'),
#   'volume': 21012796},
#  {'timestamp': datetime.datetime(2026, 6, 10, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1258.0'),
#   'high': Decimal('1276.0'),
#   'low': Decimal('1253.2'),
#   'close': Decimal('1263.0'),
#   'volume': 13117486},
#  {'timestamp': datetime.datetime(2026, 6, 11, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1277.0'),
#   'high': Decimal('1297.0'),
#   'low': Decimal('1262.5'),
#   'close': Decimal('1293.0'),
#   'volume': 11988785},
#  {'timestamp': datetime.datetime(2026, 6, 14, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1315.3'),
#   'high': Decimal('1325.0'),
#   'low': Decimal('1303.3'),
#   'close': Decimal('1307.0'),
#   'volume': 18633321},
#  {'timestamp': datetime.datetime(2026, 6, 15, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1313.4'),
#   'high': Decimal('1333.4'),
#   'low': Decimal('1306.4'),
#   'close': Decimal('1328.8'),
#   'volume': 18513223},
#  {'timestamp': datetime.datetime(2026, 6, 16, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1333.0'),
#   'high': Decimal('1334.0'),
#   'low': Decimal('1317.0'),
#   'close': Decimal('1332.7'),
#   'volume': 10029170},
#  {'timestamp': datetime.datetime(2026, 6, 17, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1330.0'),
#   'high': Decimal('1333.9'),
#   'low': Decimal('1322.0'),
#   'close': Decimal('1328.1'),
#   'volume': 15494549},
#  {'timestamp': datetime.datetime(2026, 6, 18, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1328.0'),
#   'high': Decimal('1338.2'),
#   'low': Decimal('1305.3'),
#   'close': Decimal('1309.5'),
#   'volume': 24887034},
#  {'timestamp': datetime.datetime(2026, 6, 21, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1316.7'),
#   'high': Decimal('1344.9'),
#   'low': Decimal('1314.1'),
#   'close': Decimal('1326.5'),
#   'volume': 12931213},
#  {'timestamp': datetime.datetime(2026, 6, 22, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1328.9'),
#   'high': Decimal('1333.0'),
#   'low': Decimal('1304.0'),
#   'close': Decimal('1309.5'),
#   'volume': 15400184},
#  {'timestamp': datetime.datetime(2026, 6, 23, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1305.7'),
#   'high': Decimal('1322.0'),
#   'low': Decimal('1297.5'),
#   'close': Decimal('1313.6'),
#   'volume': 11030917},
#  {'timestamp': datetime.datetime(2026, 6, 24, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1318.0'),
#   'high': Decimal('1328.0'),
#   'low': Decimal('1314.6'),
#   'close': Decimal('1318.1'),
#   'volume': 12694362},
#  {'timestamp': datetime.datetime(2026, 6, 28, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1308.0'),
#   'high': Decimal('1313.7'),
#   'low': Decimal('1292.6'),
#   'close': Decimal('1301.0'),
#   'volume': 13757656},
#  {'timestamp': datetime.datetime(2026, 6, 29, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1306.9'),
#   'high': Decimal('1306.9'),
#   'low': Decimal('1290.0'),
#   'close': Decimal('1293.9'),
#   'volume': 15695263},
#  {'timestamp': datetime.datetime(2026, 6, 30, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1298.9'),
#   'high': Decimal('1312.2'),
#   'low': Decimal('1296.5'),
#   'close': Decimal('1308.0'),
#   'volume': 7001401},
#  {'timestamp': datetime.datetime(2026, 7, 1, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1310.0'),
#   'high': Decimal('1313.2'),
#   'low': Decimal('1299.0'),
#   'close': Decimal('1303.5'),
#   'volume': 17795024},
#  {'timestamp': datetime.datetime(2026, 7, 2, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1312.0'),
#   'high': Decimal('1312.0'),
#   'low': Decimal('1302.0'),
#   'close': Decimal('1304.0'),
#   'volume': 7839550},
#  {'timestamp': datetime.datetime(2026, 7, 5, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1304.0'),
#   'high': Decimal('1325.6'),
#   'low': Decimal('1299.4'),
#   'close': Decimal('1321.3'),
#   'volume': 7610709},
#  {'timestamp': datetime.datetime(2026, 7, 6, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1323.5'),
#   'high': Decimal('1328.0'),
#   'low': Decimal('1304.1'),
#   'close': Decimal('1308.4'),
#   'volume': 14335554},
#  {'timestamp': datetime.datetime(2026, 7, 7, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1297.0'),
#   'high': Decimal('1302.3'),
#   'low': Decimal('1271.6'),
#   'close': Decimal('1275.9'),
#   'volume': 19960868},
#  {'timestamp': datetime.datetime(2026, 7, 8, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1277.1'),
#   'high': Decimal('1296.5'),
#   'low': Decimal('1274.2'),
#   'close': Decimal('1279.8'),
#   'volume': 14651963},
#  {'timestamp': datetime.datetime(2026, 7, 9, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1291.9'),
#   'high': Decimal('1311.1'),
#   'low': Decimal('1287.8'),
#   'close': Decimal('1307.8'),
#   'volume': 8412537},
#  {'timestamp': datetime.datetime(2026, 7, 12, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1300.0'),
#   'high': Decimal('1306.4'),
#   'low': Decimal('1295.0'),
#   'close': Decimal('1296.9'),
#   'volume': 9488352},
#  {'timestamp': datetime.datetime(2026, 7, 13, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1290.0'),
#   'high': Decimal('1308.0'),
#   'low': Decimal('1286.9'),
#   'close': Decimal('1293.0'),
#   'volume': 13511284},
#  {'timestamp': datetime.datetime(2026, 7, 14, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1294.1'),
#   'high': Decimal('1310.9'),
#   'low': Decimal('1294.1'),
#   'close': Decimal('1295.5'),
#   'volume': 9577965},
#  {'timestamp': datetime.datetime(2026, 7, 15, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1295.5'),
#   'high': Decimal('1309.4'),
#   'low': Decimal('1291.8'),
#   'close': Decimal('1296.6'),
#   'volume': 15631046},
#  {'timestamp': datetime.datetime(2026, 7, 16, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1300.0'),
#   'high': Decimal('1330.3'),
#   'low': Decimal('1296.1'),
#   'close': Decimal('1327.2'),
#   'volume': 18302218},
#  {'timestamp': datetime.datetime(2026, 7, 19, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1317.2'),
#   'high': Decimal('1345.9'),
#   'low': Decimal('1314.9'),
#   'close': Decimal('1323.1'),
#   'volume': 14305844},
#  {'timestamp': datetime.datetime(2026, 7, 20, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1321.0'),
#   'high': Decimal('1326.9'),
#   'low': Decimal('1302.7'),
#   'close': Decimal('1303.7'),
#   'volume': 12753410},
#  {'timestamp': datetime.datetime(2026, 7, 21, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1302.0'),
#   'high': Decimal('1304.6'),
#   'low': Decimal('1280.7'),
#   'close': Decimal('1288.6'),
#   'volume': 10840383},
#  {'timestamp': datetime.datetime(2026, 7, 22, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1283.0'),
#   'high': Decimal('1287.3'),
#   'low': Decimal('1268.0'),
#   'close': Decimal('1272.2'),
#   'volume': 12580741},
#  {'timestamp': datetime.datetime(2026, 7, 23, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1265.0'),
#   'high': Decimal('1283.4'),
#   'low': Decimal('1249.8'),
#   'close': Decimal('1278.0'),
#   'volume': 9817000},
#  {'timestamp': datetime.datetime(2026, 7, 26, 18, 30, tzinfo=datetime.timezone.utc),
#   'open': Decimal('1288.2'),
#   'high': Decimal('1288.7'),
#   'low': Decimal('1278.0'),
#   'close': Decimal('1280.0'),
#   'volume': 7163132}]

# %%
# # ──────────────────────────────────────────────────────────────────────────────
# # 1. Gateway construction
# # ──────────────────────────────────────────────────────────────────────────────

# def demo_gateway_construction():
#     """Show the three ways to create a Gateway."""
   

# # ──────────────────────────────────────────────────────────────────────────────
# # 2. Instrument resolution — three calling conventions
# # ──────────────────────────────────────────────────────────────────────────────

# def demo_instrument_resolution(gw):
#     """gw.instrument() accepts qualified strings, separate args, or domain objects."""
#     from scalpr.domain.instrument import Exchange, Segment, SimpleInstrumentId

#     # Convention 1: Qualified string
#     tcs = gw.instrument("TCS:NSE")
#     print(f"1. Qualified string:  {tcs.symbol} @ {tcs.exchange} (sid={tcs.security_id})")

#     # Convention 2: Separate args (enum or string)
#     reliance = gw.instrument("RELIANCE", Exchange.NSE)
#     print(f"2. Separate args:     {reliance.symbol} @ {reliance.exchange}")

#     # Convention 3: SimpleInstrumentId domain object
#     sid = SimpleInstrumentId(symbol="INFY", exchange=Exchange.NSE)
#     infy = gw.instrument(sid)
#     print(f"3. Domain object:     {infy.symbol} @ {infy.exchange}")

#     # Index with segment
#     nifty = gw.instrument("NIFTY", Exchange.NSE, Segment.INDEX)
#     print(f"4. Index:             {nifty.symbol} @ {nifty.exchange} (id={nifty.id})")

#     # MCX commodity
#     gold = gw.instrument("GOLD", "MCX")
#     print(f"5. Commodity:         {gold.symbol} @ {gold.exchange}")

#     return tcs, nifty


# # ──────────────────────────────────────────────────────────────────────────────
# # 3. Market data — ltp, quote, ohlc, depth, historical
# # ──────────────────────────────────────────────────────────────────────────────

# def demo_market_data(tcs):
#     """InstrumentHandle market data methods."""

#     # Last traded price
#     price = tcs.ltp()
#     print(f"LTP:  ₹{price}")

#     # Full quote (all fields)
#     q = tcs.quote()
#     print(f"Quote: open={q.get('open')} high={q.get('high')} "
#           f"low={q.get('low')} close={q.get('close')} vol={q.get('volume')}")

#     # OHLC snapshot (convenience — extracts OHLC from quote)
#     ohlc = tcs.ohlc()
#     print(f"OHLC: O={ohlc['open']} H={ohlc['high']} L={ohlc['low']} C={ohlc['close']}")

#     # Market depth (REST = 5 levels; use WS FULL for 20-level)
#     depth = tcs.depth()
#     print(f"Depth: best bid={depth.get('bids', [{}])[0].get('price', 'N/A')}, "
#           f"best ask={depth.get('asks', [{}])[0].get('price', 'N/A')}")

#     # Historical candles (default: 90 days daily)
#     candles = tcs.historical(interval="1D", start="2025-01-01", end="2025-06-30")
#     print(f"Historical: {len(candles)} candles from {candles[0]['timestamp']} "
#           f"to {candles[-1]['timestamp']}")


# # ──────────────────────────────────────────────────────────────────────────────
# # 4. Option chain — with moneyness filtering
# # ──────────────────────────────────────────────────────────────────────────────

# def demo_option_chain(nifty):
#     """Option chain with ATM/ITM/OTM filtering."""

#     # ── Raw chain (all strikes, both CE and PE) ──
#     all_legs = nifty.option_chain()
#     print(f"\nRaw chain: {len(all_legs)} legs")
#     print(f"  Sample: strike={all_legs[0]['strike']} "
#           f"type={all_legs[0]['option_type']} "
#           f"bid={all_legs[0]['bid']} ask={all_legs[0]['ask']}")

#     # ── ATM only (strikes within 0.5% of spot) ──
#     atm = nifty.option_chain(moneyness="ATM")
#     print(f"\nATM legs: {len(atm)}")
#     for leg in atm:
#         print(f"  {leg['option_type']:2s} strike={leg['strike']:>10} "
#               f"bid={leg['bid']:>8} ask={leg['ask']:>8} "
#               f"oi={leg['oi']:>10} delta={leg.get('delta')}")

#     # ── ITM only ──
#     itm = nifty.option_chain(moneyness="ITM")
#     print(f"\nITM legs: {len(itm)}")

#     # ── OTM only ──
#     otm = nifty.option_chain(moneyness="OTM")
#     print(f"\nOTM legs: {len(otm)}")

#     # ── Combination: ATM + ITM ──
#     atm_itm = nifty.option_chain(moneyness="ATM,ITM")
#     print(f"\nATM+ITM legs: {len(atm_itm)}")

#     # ── N strikes around ATM ──
#     around = nifty.option_chain(strikes_around=3)
#     strikes = sorted(set(leg["strike"] for leg in around))
#     print(f"\n3 strikes around ATM: {len(around)} legs across {len(strikes)} strikes")
#     print(f"  Strikes: {strikes}")

#     # ── Filter by option type ──
#     ce_only = nifty.option_chain(option_type="CE")
#     pe_only = nifty.option_chain(option_type="PE")
#     print(f"\nCE legs: {len(ce_only)}, PE legs: {len(pe_only)}")

#     # ── Combined: ATM calls, 2 strikes around ──
#     atm_ce = nifty.option_chain(moneyness="ATM", strikes_around=2, option_type="CE")
#     print(f"\nATM CE (2 around): {len(atm_ce)} legs")
#     for leg in atm_ce:
#         print(f"  {leg['option_type']} strike={leg['strike']} "
#               f"moneyness={leg['moneyness']} spot={leg['spot_price']}")

#     # ── Specific expiry ──
#     chain_expiry = nifty.option_chain(expiry=date(2026, 8, 28), moneyness="ATM")
#     print(f"\nATM for 2026-08-28 expiry: {len(chain_expiry)} legs")


# # ──────────────────────────────────────────────────────────────────────────────
# # 5. Option chain — error handling
# # ──────────────────────────────────────────────────────────────────────────────

# def demo_option_chain_error(tcs):
#     """Equities don't support option chain — clear error."""
#     from scalpr.brokers.errors import OptionChainNotSupported

#     try:
#         tcs.option_chain()
#     except OptionChainNotSupported as e:
#         print(f"\n✓ TCS.option_chain() correctly rejected:")
#         print(f"  {e}")


# # ──────────────────────────────────────────────────────────────────────────────
# # 6. Live feed — subscribe / unsubscribe
# # ──────────────────────────────────────────────────────────────────────────────

# def demo_live_feed(gw):
#     """Subscribe to live market data via WebSocket."""
#     from scalpr.domain.instrument import MarketFeed

#     def handle_tick(event):
#         print(f"  tick: {event}")

#     # Subscribe multiple instruments
#     gw.subscribe_feed(
#         MarketFeed.QUOTE,
#         ["TCS:NSE", "RELIANCE:NSE", "NIFTY:NSE"],
#         on_event=handle_tick,
#     )
#     print("Subscribed to QUOTE feed for TCS, RELIANCE, NIFTY")

#     # Unsubscribe
#     gw.unsubscribe(["RELIANCE:NSE"])
#     print("Unsubscribed RELIANCE")

#     # Clean shutdown
#     gw.close()
#     print("Gateway closed")


# # ──────────────────────────────────────────────────────────────────────────────
# # 7. Per-instrument subscribe
# # ──────────────────────────────────────────────────────────────────────────────

# def demo_instrument_subscribe(nifty):
#     """Subscribe to a single instrument via its handle."""
#     from scalpr.domain.instrument import MarketFeed

#     def on_tick(event):
#         print(f"  NIFTY tick: {event}")

#     nifty.subscribe(MarketFeed.FULL, on_tick)
#     print("Subscribed to NIFTY FULL feed via handle")


# # ──────────────────────────────────────────────────────────────────────────────
# # 8. Gateway-level option chain (legacy path)
# # ──────────────────────────────────────────────────────────────────────────────

# def demo_gateway_option_chain(gw):
#     """Gateway.option_chain() — works but prefer handle.option_chain()."""
#     chain = gw.option_chain("NIFTY", "NSE")
#     print(f"Gateway option_chain: {len(chain)} legs")


# # ──────────────────────────────────────────────────────────────────────────────
# # Main
# # ──────────────────────────────────────────────────────────────────────────────

# def main():
#     print("=" * 60)
#     print("TradeXV2 Gateway API — Examples")
#     print("=" * 60)

#     # 1. Create gateway
#     print("\n── 1. Gateway Construction ──")
#     gw = demo_gateway_construction()

#     # 2. Resolve instruments
#     print("\n── 2. Instrument Resolution ──")
#     tcs, nifty = demo_instrument_resolution(gw)

#     # 3. Market data
#     print("\n── 3. Market Data ──")
#     demo_market_data(tcs)

#     # 4. Option chain with filtering
#     print("\n── 4. Option Chain (filtered) ──")
#     demo_option_chain(nifty)

#     # 5. Error handling
#     print("\n── 5. Option Chain Error ──")
#     demo_option_chain_error(tcs)

#     print("\n" + "=" * 60)
#     print("Done.")


# if __name__ == "__main__":
#     main()
